# %%
import numpy as np
import pandas as pd

from data_scraper import get_data
from data_analyser import get_daily_growth, get_growth_rate

# %%
covid19_data = get_data()
berlin = covid19_data[covid19_data.region=="Berlin"]
berlin.plot(x="date", y=["confirmed", "recovered", "deaths"], title="covid19 data")

# %%
daily_growth = get_daily_growth(covid19_data)
berlin = daily_growth[daily_growth.region=="Berlin"]
berlin.plot(x="date", y=["confirmed", "recovered", "deaths"], title="covid19 daily growth")

# %%
growth_rate = get_growth_rate(covid19_data)
berlin = growth_rate[growth_rate.region=="Berlin"]
berlin.plot(x="date", y=["confirmed"], title="covid19 growth rate")

# %%
berlin = growth_rate[growth_rate.region=="Italien"]
berlin.plot(x="date", y=["confirmed"], title="covid19 growth rate", ylim=(0, 2))

# %%
covid19_data
# Out:
#            date parent_region            region  confirmed  recovered  deaths
# 0    2020-01-27         China  Peking (Beijing)       80.0        2.0     1.0
# 1    2020-01-27         China             Henan      128.0        0.0     1.0
# 2    2020-01-27           USA          Illinois        1.0        0.0     0.0
# 3    2020-01-27           USA        California        2.0        0.0     0.0
# 4    2020-01-27         China            Hainan       33.0        0.0     1.0
# ...         ...           ...               ...        ...        ...     ...
# 6761 2020-03-15        global       USA (total)     3453.0       12.0    63.0
# 6762 2020-03-16        global       USA (total)     4585.0       17.0    85.0
# 6763 2020-03-17        global       USA (total)     6374.0       17.0   108.0
# 6764 2020-03-18        global       USA (total)     7736.0        0.0   118.0
# 6765 2020-03-19        global       USA (total)    13630.0        0.0   200.0
#
# [6766 rows x 6 columns]

# %%
growth_rate[(growth_rate.region=="Italien") | (growth_rate.region=="Berlin")]
# Out:
#            date parent_region   region  confirmed  recovered    deaths
# 286  2020-02-02        global  Italien   0.000000   0.000000  0.000000
# 355  2020-02-03        global  Italien   0.000000   0.000000  0.000000
# 426  2020-02-04        global  Italien   0.000000   0.000000  0.000000
# 497  2020-02-05        global  Italien   0.000000   0.000000  0.000000
# 569  2020-02-06        global  Italien   0.000000   0.000000  0.000000
# ...         ...           ...      ...        ...        ...       ...
# 5498 2020-03-17        global  Italien   0.916643   2.145078  1.008671
# 5632 2020-03-18   Deutschland   Berlin   0.372263   0.166667  0.000000
# 5775 2020-03-18        global  Italien   0.837928   0.176959  0.724790
# 5912 2020-03-19   Deutschland   Berlin   0.800000   5.000000  0.000000
# 6064 2020-03-19        global  Italien   0.790344   2.605769  1.109813
#
# [62 rows x 6 columns]

# %%
selector = pd.DataFrame([growth_rate.region=="Italien", growth_rate.region=="Berlin"]).apply(lambda row: any(row))
growth_rate[selector].region.unique()
# Out:
# array(['Italien', 'Berlin'], dtype=object)

# %%
selector
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6154    False
# 6155    False
# 6156    False
# 6157    False
# 6158    False
# Length: 6159, dtype: bool
